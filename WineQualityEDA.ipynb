# %% [markdown]
# ## EDA With Red Wine Data

# %% [markdown]
# #### Data Set Information:
#
# ##### The datasets is related to red wine.  Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# ##### These datasets can be viewed as classification or regression tasks. The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Outlier detection algorithms could be used to detect the few excellent or poor wines. Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.
#
#
# Attribute Information:
#
# Input variables (based on physicochemical tests):
# - 1 - fixed acidity
# - 2 - volatile acidity
# - 3 - citric acid
# - 4 - residual sugar
# - 5 - chlorides
# - 6 - free sulfur dioxide
# - 7 - total sulfur dioxide
# - 8 - density
# - 9 - pH
# - 10 - sulphates
# - 11 - alcohol
#
# Output variable (based on sensory data):
# - 12 - quality (score between 0 and 10)

# %%
# Import the pandas library, which is essential for data manipulation and analysis.
import pandas as pd
# Import seaborn for visualization
import seaborn as sns 
# Import matplotlib for plotting
import matplotlib.pyplot as plt  

# Read the CSV file, specifying the semicolon (;) as the delimiter since the data is separated by semicolons.
df = pd.read_csv('winequality-red.csv', delimiter=';')

# Display the first few rows of the DataFrame to verify that the data has been loaded correctly.
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Display a concise summary of the DataFrame, including the number of non-null entries and the data type of each column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Generate a descriptive summary of the dataset, which includes statistical measures for each numerical column.
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# Get the shape of the DataFrame, which returns a tuple representing the dimensions of the dataset.
df.shape
# Out:
# (1599, 12)

# %%
# List all the column names in the DataFrame.
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Get the unique values in the 'quality' column.
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
# Check for missing values in each column of the DataFrame.
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Find and display all duplicate records in the DataFrame.
df[df.duplicated()]
# df.drop_duplicates(inplace=True), it will keep the first occurrence of each duplicate row and remove the subsequent duplicates.
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
# Remove duplicate records from the DataFrame.
df.drop_duplicates(inplace=True)

# %%
# Get the shape of the DataFrame after removing duplicates.
df.shape
# Out:
# (1359, 12)

# %%
# Calculate the correlation matrix for the DataFrame.
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# ### Key Observations from Your Correlation Matrix
#
# fixed acidity:
# Strong positive correlation with citric acid (0.67) and density (0.67).
# Strong negative correlation with pH (-0.69).
#
# volatile acidity:
# Strong negative correlation with citric acid (-0.55) and quality (-0.40).
# Positive correlation with sulphates (0.25).
#
# citric acid:
# Strong positive correlation with fixed acidity (0.67) and density (0.36).
# Strong negative correlation with pH (-0.55).
#
# residual sugar:
# Mild positive correlation with fixed acidity (0.11) and total sulfur dioxide (0.20).
# Very weak correlation with quality (0.01).
#
# chlorides:
# Moderate positive correlation with sulphates (0.39) and negative correlation with pH (-0.27).
#
# free sulfur dioxide:
# Strong positive correlation with total sulfur dioxide (0.67).
# Mild negative correlation with quality (-0.05).
#
# total sulfur dioxide:
# Strong positive correlation with free sulfur dioxide (0.67).
# Weak negative correlation with quality (-0.18).
#
# density:
# Strong positive correlation with fixed acidity (0.67) and citric acid (0.36).
# Strong negative correlation with alcohol (-0.50) and pH (-0.36).
#
# pH:
# Strong negative correlation with fixed acidity (-0.69) and citric acid (-0.55).
# Mild positive correlation with sulphates (-0.21).
#
# sulphates:
# Mild positive correlation with fixed acidity (0.19) and quality (0.25).
# Positive correlation with chlorides (0.39).
#
# alcohol:
# Strong positive correlation with quality (0.48).
# Strong negative correlation with density (-0.50).
#
# quality:
# Strong positive correlation with alcohol (0.48).
# Negative correlation with volatile acidity (-0.40) and pH (-0.06).

# %%
# Calculate the correlation matrix for the DataFrame.
correlation_matrix = df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Draw the heatmap
sns.heatmap(
    correlation_matrix,           # The data to plot
    annot=True,                    # Annotate each cell with the numeric value
    annot_kws={"size": 10},        # Adjust annotation font size
    cmap='coolwarm',               # Color map
    vmin=-1, vmax=1,               # Color scale range
    center=0,                      # Center of the color map
    fmt='.2f',                    # Format for the annotation text (two decimal places)
    linewidths=.5,                # Width of lines that will divide each cell
    square=True,                  # Make the heatmap square-shaped
    cbar_kws={"shrink": .8}       # Shrink colorbar for better fit
)

# Add titles and labels
plt.title('Correlation Matrix Heatmap', fontsize=16)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels
plt.yticks(rotation=0)               # Rotate y-axis labels

# Display the plot
plt.show()

# %%
# Plot the distribution of 'quality' values
df['quality'].value_counts().sort_index().plot(kind='bar', color='skyblue')

# Add title and labels
plt.title('Distribution of Wine Quality Ratings')
plt.xlabel('Quality')
plt.ylabel('Frequency')
ax.set_yticks(ax.get_yticks())  # Ensure y-ticks are only the actual counts

# Show the plot
plt.show()

# %% [markdown]
# ### Imbalanced Distribution:
#
# ##### The wine quality dataset is imbalanced, meaning that the distribution of quality ratings is uneven. Specifically:
# ##### Quality 5 and Quality 6 have the highest counts, with 577 and 535 wines, respectively.
# ##### Quality 3 and Quality 8 have the lowest counts, with 10 and 17 wines, respectively.

# %%
# Display the first few rows
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Loop through each column in the DataFrame
for column in df.columns:
    plt.figure(figsize=(8, 4))  # Set smaller figure size for each histogram
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
# Optional: Select a subset of columns for the pairplot if there are many
subset_columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'quality']
df_subset = df[subset_columns]

# Create the pairplot
sns.pairplot(df_subset)
plt.suptitle('Pairplot of Selected Features', y=1.02)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='alcohol', y='pH', hue='quality', data=df, palette='viridis', s=100, alpha=0.7)

# Customize the plot
plt.title('Scatter Plot of Alcohol vs. pH by Wine Quality')
plt.xlabel('Alcohol')
plt.ylabel('pH')
plt.legend(title='Quality')
plt.grid(True)

# Show the plot
plt.show()
